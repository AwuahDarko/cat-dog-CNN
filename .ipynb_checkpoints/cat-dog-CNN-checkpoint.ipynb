# %%
import numpy as np
import cv2
import os
# Added because of this error
# Error #15: Initializing libiomp5.dylib, but found libomp.dylib already initialized.
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['CUDA_VISIBLE_DEVICES'] = 'True'
# =============================================
import random
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.layers import Activation, Dense, Flatten,Conv2D, MaxPool2D

# %%
DIRECTORY = "/Users/macbookpro/Documents/AI/datasets/dogs-vs-cats/train"
TEST_DIRECTORY = "/Users/macbookpro/Documents/AI/datasets/dogs-vs-cats/test"
# 0 is cat, 1 is dog
CATEGORIES = ['cat', 'dog']

# %%
IMG_SIZE = 90
data = []

# %%
for img in os.listdir(DIRECTORY):
    img_path = os.path.join(DIRECTORY, img)
    img_arr = cv2.imread(img_path)
    img_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))

    if img.find("dog") > -1:
        data.append([img_arr, 1])
    elif img.find("cat") > -1:
        data.append([img_arr, 0])
#     plt.imshow(img_arr)

# %%
data[1000][1]
# Out:
# 0

# %%
plt.imshow(data[1000][0])

# %%
len(data)
# Out:
# 25000

# %%
random.shuffle(data)

# %%
train_samples = []
train_labels = []

# %%
for features, labels in data:
    train_samples.append(features)
    train_labels.append(labels)

# %%
train_samples = np.array(train_samples)
train_labels = np.array(train_labels)

# %%
# save to continue later
pickle.dump(train_samples, open('train_samples.pkl', 'wb'))
pickle.dump(train_labels, open('train_labels.pkl', 'wb'))

# %%
# load saved data
train_samples = pickle.load(open('train_samples.pkl', 'rb'))
train_labels = pickle.load(open('train_labels.pkl', 'rb'))

# %%
train_labels
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
plt.imshow(train_samples[1701])

# %%
plt.imshow(train_samples[2841])

# %%
# feature scaling
train_samples = train_samples/255
train_samples
# Out:
# array([[[[0.05098039, 0.10980392, 0.09019608],
#          [0.05882353, 0.12156863, 0.09411765],
#          [0.03137255, 0.07058824, 0.10588235],
#          ...,
#          [0.20784314, 0.17254902, 0.2       ],
#          [0.1372549 , 0.1254902 , 0.12156863],
#          [0.03137255, 0.05490196, 0.01568627]],
#
#         [[0.05098039, 0.06666667, 0.04313725],
#          [0.0745098 , 0.09803922, 0.05490196],
#          [0.03529412, 0.04705882, 0.03921569],
#          ...,
#          [0.15686275, 0.15686275, 0.11764706],
#          [0.1372549 , 0.13333333, 0.12156863],
#          [0.05098039, 0.03529412, 0.05490196]],
#
#         [[0.04313725, 0.05882353, 0.09019608],
#          [0.05098039, 0.07843137, 0.07058824],
#          [0.03137255, 0.05490196, 0.0627451 ],
#          ...,
#          [0.30980392, 0.3254902 , 0.30980392],
#          [0.29411765, 0.28627451, 0.28235294],
#          [0.23921569, 0.21568627, 0.21176471]],
#
#         ...,
#
#         [[0.19215686, 0.34901961, 0.5372549 ],
#          [0.23921569, 0.36862745, 0.54901961],
#          [0.25098039, 0.40392157, 0.57254902],
#          ...,
#          [0.96078431, 0.87058824, 0.84313725],
#          [0.95686275, 0.86666667, 0.85882353],
#          [0.8745098 , 0.83529412, 0.84313725]],
#
#         [[0.16862745, 0.36862745, 0.54509804],
#          [0.16862745, 0.34901961, 0.50980392],
#          [0.23529412, 0.43921569, 0.58039216],
#          ...,
#          [0.94509804, 0.8627451 , 0.85882353],
#          [0.97647059, 0.86666667, 0.86666667],
#          [0.90588235, 0.83529412, 0.82352941]],
#
#         [[0.21960784, 0.39607843, 0.54117647],
#          [0.11372549, 0.30196078, 0.49019608],
#          [0.20392157, 0.42745098, 0.60392157],
#          ...,
#          [0.94509804, 0.85098039, 0.85098039],
#          [0.90588235, 0.83137255, 0.81176471],
#          [0.92941176, 0.87843137, 0.84705882]]],
#
#
#        [[[0.83529412, 0.73333333, 0.73333333],
#          [0.85098039, 0.74901961, 0.74901961],
#          [0.84313725, 0.74117647, 0.74117647],
#          ...,
#          [0.95294118, 0.86666667, 0.84313725],
#          [0.95294118, 0.87058824, 0.84705882],
#          [0.94901961, 0.90196078, 0.8627451 ]],
#
#         [[0.84313725, 0.74117647, 0.74117647],
#          [0.84705882, 0.74509804, 0.74509804],
#          [0.85098039, 0.74901961, 0.74901961],
#          ...,
#          [0.92156863, 0.88235294, 0.85098039],
#          [0.93333333, 0.89411765, 0.85882353],
#          [0.94509804, 0.89803922, 0.85490196]],
#
#         [[0.83921569, 0.7372549 , 0.7372549 ],
#          [0.84705882, 0.74509804, 0.74509804],
#          [0.85098039, 0.74901961, 0.74901961],
#          ...,
#          [0.9254902 , 0.8745098 , 0.84313725],
#          [0.9372549 , 0.88627451, 0.85490196],
#          [0.92156863, 0.8745098 , 0.83529412]],
#
#         ...,
#
#         [[0.5254902 , 0.48235294, 0.51372549],
#          [0.54509804, 0.50196078, 0.53333333],
#          [0.54117647, 0.49803922, 0.53333333],
#          ...,
#          [0.74509804, 0.71372549, 0.71764706],
#          [0.74509804, 0.71372549, 0.71764706],
#          [0.77647059, 0.74509804, 0.74901961]],
#
#         [[0.51764706, 0.4745098 , 0.50588235],
#          [0.50588235, 0.4627451 , 0.49411765],
#          [0.50196078, 0.45882353, 0.49019608],
#          ...,
#          [0.74509804, 0.71372549, 0.71764706],
#          [0.75294118, 0.72156863, 0.7254902 ],
#          [0.75294118, 0.72156863, 0.7254902 ]],
#
#         [[0.48235294, 0.43921569, 0.47058824],
#          [0.51372549, 0.47058824, 0.50196078],
#          [0.51764706, 0.47058824, 0.50588235],
#          ...,
#          [0.7372549 , 0.70588235, 0.70980392],
#          [0.75294118, 0.72156863, 0.7254902 ],
#          [0.79607843, 0.76470588, 0.76862745]]],
#
#
#        [[[0.70196078, 0.70196078, 0.70196078],
#          [0.49019608, 0.50196078, 0.52156863],
#          [0.46666667, 0.49411765, 0.52941176],
#          ...,
#          [0.12156863, 0.1372549 , 0.15686275],
#          [0.10196078, 0.11764706, 0.1372549 ],
#          [0.07058824, 0.11372549, 0.12941176]],
#
#         [[0.48627451, 0.49411765, 0.50980392],
#          [0.74117647, 0.75686275, 0.77254902],
#          [0.49803922, 0.51764706, 0.5372549 ],
#          ...,
#          [0.1372549 , 0.16078431, 0.18039216],
#          [0.10980392, 0.1372549 , 0.15294118],
#          [0.07843137, 0.12156863, 0.1372549 ]],
#
#         [[0.4627451 , 0.48627451, 0.51372549],
#          [0.5372549 , 0.54901961, 0.56862745],
#          [0.74901961, 0.75686275, 0.76470588],
#          ...,
#          [0.1254902 , 0.16862745, 0.18431373],
#          [0.11372549, 0.15686275, 0.17254902],
#          [0.10196078, 0.14509804, 0.16078431]],
#
#         ...,
#
#         [[0.7372549 , 0.72941176, 0.72941176],
#          [0.60392157, 0.59607843, 0.59607843],
#          [0.70588235, 0.69803922, 0.69803922],
#          ...,
#          [0.46666667, 0.4627451 , 0.46666667],
#          [0.40784314, 0.43529412, 0.44705882],
#          [0.41568627, 0.42352941, 0.44705882]],
#
#         [[0.71372549, 0.70980392, 0.70980392],
#          [0.6627451 , 0.65490196, 0.65882353],
#          [0.61960784, 0.61176471, 0.61568627],
#          ...,
#          [0.48627451, 0.4745098 , 0.4745098 ],
#          [0.41960784, 0.44705882, 0.45490196],
#          [0.41176471, 0.42352941, 0.44705882]],
#
#         [[0.65882353, 0.65490196, 0.6627451 ],
#          [0.59215686, 0.58823529, 0.59607843],
#          [0.71764706, 0.70980392, 0.71764706],
#          ...,
#          [0.61568627, 0.61568627, 0.59607843],
#          [0.42352941, 0.44313725, 0.44705882],
#          [0.40392157, 0.41176471, 0.44313725]]],
#
#
#        ...,
#
#
#        [[[0.20784314, 0.41960784, 0.6745098 ],
#          [0.20392157, 0.40392157, 0.63921569],
#          [0.41960784, 0.59215686, 0.77647059],
#          ...,
#          [0.44705882, 0.69803922, 0.85882353],
#          [0.30196078, 0.54901961, 0.68235294],
#          [0.27843137, 0.51764706, 0.61176471]],
#
#         [[0.25490196, 0.50980392, 0.76078431],
#          [0.34117647, 0.56470588, 0.78431373],
#          [0.44313725, 0.61960784, 0.78431373],
#          ...,
#          [0.51764706, 0.75294118, 0.90980392],
#          [0.45098039, 0.67843137, 0.81568627],
#          [0.4       , 0.61568627, 0.7254902 ]],
#
#         [[0.30980392, 0.6       , 0.82745098],
#          [0.34509804, 0.58431373, 0.76862745],
#          [0.22745098, 0.38823529, 0.50588235],
#          ...,
#          [0.39215686, 0.60392157, 0.74901961],
#          [0.55686275, 0.76078431, 0.89019608],
#          [0.2745098 , 0.4627451 , 0.58823529]],
#
#         ...,
#
#         [[0.75686275, 0.77254902, 0.80784314],
#          [0.75294118, 0.77254902, 0.80784314],
#          [0.78823529, 0.80784314, 0.84313725],
#          ...,
#          [0.52941176, 0.68627451, 0.88235294],
#          [0.1372549 , 0.32156863, 0.5254902 ],
#          [0.38039216, 0.57647059, 0.78431373]],
#
#         [[0.74901961, 0.76862745, 0.80392157],
#          [0.74901961, 0.76862745, 0.80392157],
#          [0.76078431, 0.78039216, 0.81568627],
#          ...,
#          [0.56862745, 0.73333333, 0.94117647],
#          [0.56470588, 0.74509804, 0.9372549 ],
#          [0.52156863, 0.71372549, 0.89019608]],
#
#         [[0.75294118, 0.77254902, 0.80784314],
#          [0.75686275, 0.77647059, 0.81176471],
#          [0.73333333, 0.75294118, 0.78823529],
#          ...,
#          [0.30196078, 0.4745098 , 0.68627451],
#          [0.4627451 , 0.64313725, 0.82745098],
#          [0.01176471, 0.20392157, 0.34509804]]],
#
#
#        [[[0.11764706, 0.56862745, 0.41176471],
#          [0.14901961, 0.56078431, 0.41176471],
#          [0.15294118, 0.52156863, 0.37647059],
#          ...,
#          [0.79215686, 0.78823529, 0.69019608],
#          [0.76470588, 0.76470588, 0.6745098 ],
#          [0.79607843, 0.8       , 0.72156863]],
#
#         [[0.16470588, 0.6       , 0.45490196],
#          [0.17647059, 0.60392157, 0.45490196],
#          [0.19607843, 0.61568627, 0.47058824],
#          ...,
#          [0.7254902 , 0.77647059, 0.6745098 ],
#          [0.75686275, 0.79215686, 0.70196078],
#          [0.78039216, 0.78823529, 0.71372549]],
#
#         [[0.16078431, 0.58431373, 0.44313725],
#          [0.1372549 , 0.58039216, 0.43529412],
#          [0.18431373, 0.65490196, 0.50588235],
#          ...,
#          [0.39215686, 0.47843137, 0.38039216],
#          [0.69803922, 0.75686275, 0.66666667],
#          [0.76862745, 0.77254902, 0.70980392]],
#
#         ...,
#
#         [[0.25490196, 0.56862745, 0.45490196],
#          [0.12941176, 0.4745098 , 0.35686275],
#          [0.04313725, 0.42352941, 0.29803922],
#          ...,
#          [0.20392157, 0.5372549 , 0.45882353],
#          [0.27058824, 0.56470588, 0.50196078],
#          [0.24705882, 0.5372549 , 0.49019608]],
#
#         [[0.2627451 , 0.59607843, 0.47058824],
#          [0.27843137, 0.63137255, 0.50196078],
#          [0.14509804, 0.51764706, 0.38431373],
#          ...,
#          [0.2627451 , 0.63137255, 0.49803922],
#          [0.10980392, 0.4745098 , 0.36470588],
#          [0.21568627, 0.58039216, 0.49803922]],
#
#         [[0.14117647, 0.48235294, 0.35294118],
#          [0.12941176, 0.48627451, 0.35686275],
#          [0.17647059, 0.54901961, 0.41568627],
#          ...,
#          [0.16862745, 0.54117647, 0.40784314],
#          [0.18823529, 0.55294118, 0.44313725],
#          [0.1372549 , 0.50196078, 0.41960784]]],
#
#
#        [[[0.9254902 , 0.89803922, 0.89803922],
#          [0.90980392, 0.87843137, 0.87843137],
#          [0.9372549 , 0.90588235, 0.90588235],
#          ...,
#          [0.9372549 , 0.91372549, 0.91764706],
#          [0.92156863, 0.89803922, 0.90196078],
#          [0.93333333, 0.91372549, 0.90980392]],
#
#         [[0.91764706, 0.88235294, 0.88235294],
#          [0.9254902 , 0.89803922, 0.89803922],
#          [0.9254902 , 0.89411765, 0.89411765],
#          ...,
#          [0.97647059, 0.95294118, 0.95686275],
#          [0.95294118, 0.93333333, 0.9372549 ],
#          [0.91372549, 0.89411765, 0.89019608]],
#
#         [[0.92156863, 0.89019608, 0.89019608],
#          [0.92156863, 0.88627451, 0.88627451],
#          [0.91764706, 0.89019608, 0.89019608],
#          ...,
#          [0.9254902 , 0.90196078, 0.90588235],
#          [0.92941176, 0.90588235, 0.90980392],
#          [0.94117647, 0.92156863, 0.91764706]],
#
#         ...,
#
#         [[0.42745098, 0.47058824, 0.57254902],
#          [0.30588235, 0.34509804, 0.41960784],
#          [0.38431373, 0.44705882, 0.51372549],
#          ...,
#          [0.50196078, 0.52156863, 0.58039216],
#          [0.45490196, 0.4745098 , 0.53333333],
#          [0.53333333, 0.55294118, 0.61176471]],
#
#         [[0.27058824, 0.30196078, 0.37254902],
#          [0.43137255, 0.44705882, 0.49411765],
#          [0.75294118, 0.76862745, 0.81568627],
#          ...,
#          [0.58823529, 0.58823529, 0.65098039],
#          [0.51372549, 0.51372549, 0.57647059],
#          [0.39607843, 0.41568627, 0.4745098 ]],
#
#         [[0.49803922, 0.50196078, 0.55294118],
#          [0.38823529, 0.38431373, 0.42745098],
#          [0.6745098 , 0.67058824, 0.70588235],
#          ...,
#          [0.60784314, 0.6       , 0.65882353],
#          [0.61960784, 0.60784314, 0.67058824],
#          [0.55686275, 0.56078431, 0.61960784]]]])

# %%
train_samples.shape
# Out:
# (25000, 90, 90, 3)

# %%
train_samples.shape[1:]
# Out:
# (90, 90, 3)

# %%
model = Sequential([
    Conv2D(filters=64, kernel_size=(3,3), activation='relu', input_shape=train_samples.shape[1:]),
    MaxPool2D(pool_size=(3,3),strides=2),
    
    Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
    MaxPool2D(pool_size=(3,3),strides=2),
    
    Flatten(),
    
    Dense(units=128, activation='relu'),
    Dense(units=200, activation='relu'),
    Dense(units=12, activation='relu'),
    Dense(units=2, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 88, 88, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 43, 43, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 41, 41, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 20, 20, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1638528
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               25800
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                2412
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 26
# =================================================================
# Total params: 1,687,022
# Trainable params: 1,687,022
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x=train_samples, y=train_labels, validation_split=0.1, epochs=10,  batch_size=500, shuffle=True)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/10
# 11500/22500 [==============>...............] - ETA: 1:11 - loss: 0.7060 - accuracy: 0.5032
